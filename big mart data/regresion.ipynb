# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train=pd.read_csv("bigmart_train.csv")
test=pd.read_csv("bigmart_test.csv")

# %%
train.shape,test.shape
# Out:
# ((8523, 12), (5681, 11))

# %%
train.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
test['Item_Outlet_Sales']="test"

# %%
train.shape,test.shape
# Out:
# ((8523, 12), (5681, 12))

# %%
train.isnull().sum().sort_values(ascending=False)
# Out:
# Outlet_Size                  2410
# Item_Weight                  1463
# Item_Identifier                 0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
test.isnull().sum().sort_values(ascending=False)
# Out:
# Outlet_Size                  1606
# Item_Weight                   976
# Item_Identifier                 0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df=pd.concat([train,test],axis=0)

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15         9.30          Low Fat         0.016047
# 1              DRC01         5.92          Regular         0.019278
# 2              FDN15        17.50          Low Fat         0.016760
# 3              FDX07        19.20          Regular         0.000000
# 4              NCD19         8.93          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 5676           FDB58        10.50          Regular         0.013496
# 5677           FDD47         7.60          Regular         0.142991
# 5678           NCO17        10.00          Low Fat         0.073529
# 5679           FDJ26        15.30          Regular         0.000000
# 5680           FDU37         9.50          Regular         0.104720
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Outlet_Size                  4016
# Item_Weight                  2439
# Item_Identifier                 0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df.Outlet_Size.mode()
# Out:
# 0    Medium
# dtype: object

# %%
df['Outlet_Size']=df['Outlet_Size'].fillna(df.Outlet_Size.mode()[0])

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Item_Weight                  2439
# Item_Identifier                 0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                     0
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df.Outlet_Size.value_counts(dropna=False)
# Out:
# Medium    8671
# Small     3980
# High      1553
# Name: Outlet_Size, dtype: int64

# %%
df.Item_Weight.describe()
# Out:
# count    11765.000000
# mean        12.792854
# std          4.652502
# min          4.555000
# 25%          8.710000
# 50%         12.600000
# 75%         16.750000
# max         21.350000
# Name: Item_Weight, dtype: float64

# %%
df["Item_Weight"]=df["Item_Weight"].fillna(df["Item_Weight"].mean())

# %%
df.Item_Weight.describe()
# Out:
# count    14204.000000
# mean        12.792854
# std          4.234226
# min          4.555000
# 25%          9.300000
# 50%         12.792854
# 75%         16.000000
# max         21.350000
# Name: Item_Weight, dtype: float64

# %%
#lable encoding
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales             object
# dtype: object

# %%
objcol=df[["Item_Identifier","Item_Fat_Content","Item_Type","Outlet_Identifier","Outlet_Size","Outlet_Location_Type","Outlet_Type"]]

# %%
objcol
# Out:
#      Item_Identifier Item_Fat_Content              Item_Type  \
# 0              FDA15          Low Fat                  Dairy
# 1              DRC01          Regular            Soft Drinks
# 2              FDN15          Low Fat                   Meat
# 3              FDX07          Regular  Fruits and Vegetables
# 4              NCD19          Low Fat              Household
# ...              ...              ...                    ...
# 5676           FDB58          Regular            Snack Foods
# 5677           FDD47          Regular          Starchy Foods
# 5678           NCO17          Low Fat     Health and Hygiene
# 5679           FDJ26          Regular                 Canned
# 5680           FDU37          Regular                 Canned
#
#      Outlet_Identifier Outlet_Size Outlet_Location_Type        Outlet_Type
# 0               OUT049      Medium               Tier 1  Supermarket Type1
# 1               OUT018      Medium               Tier 3  Supermarket Type2
# ...

# %%
obj=objcol.apply(le.fit_transform)

# %%
obj
# Out:
#       Item_Identifier  Item_Fat_Content  Item_Type  Outlet_Identifier  \
# 0                 156                 1          4                  9
# 1                   8                 2         14                  3
# 2                 662                 1         10                  9
# 3                1121                 2          6                  0
# 4                1297                 1          9                  1
# ...               ...               ...        ...                ...
# 5676              233                 2         13                  8
# 5677              308                 2         15                  3
# 5678             1426                 1          8                  7
# 5679              521                 2          3                  2
# 5680              997                 2          3                  7
#
#       Outlet_Size  Outlet_Location_Type  Outlet_Type
# 0               1                     0            1
# ...

# %%
df=df.drop(["Item_Identifier","Item_Fat_Content","Item_Type","Outlet_Identifier","Outlet_Size","Outlet_Location_Type","Outlet_Type"],axis=1)

# %%
df
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0            9.30         0.016047  249.8092                       1999
# 1            5.92         0.019278   48.2692                       2009
# 2           17.50         0.016760  141.6180                       1999
# 3           19.20         0.000000  182.0950                       1998
# 4            8.93         0.000000   53.8614                       1987
# ...           ...              ...       ...                        ...
# 5676        10.50         0.013496  141.3154                       1997
# 5677         7.60         0.142991  169.1448                       2009
# 5678        10.00         0.073529  118.7440                       2002
# 5679        15.30         0.000000  214.6218                       2007
# 5680         9.50         0.104720   79.7960                       2002
#
#      Item_Outlet_Sales
# 0             3735.138
# 1             443.4228
# 2              2097.27
# ...

# %%
dff=pd.concat([df,obj],axis=1)

# %%
dff
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0            9.30         0.016047  249.8092                       1999
# 1            5.92         0.019278   48.2692                       2009
# 2           17.50         0.016760  141.6180                       1999
# 3           19.20         0.000000  182.0950                       1998
# 4            8.93         0.000000   53.8614                       1987
# ...           ...              ...       ...                        ...
# 5676        10.50         0.013496  141.3154                       1997
# 5677         7.60         0.142991  169.1448                       2009
# 5678        10.00         0.073529  118.7440                       2002
# 5679        15.30         0.000000  214.6218                       2007
# 5680         9.50         0.104720   79.7960                       2002
#
#      Item_Outlet_Sales  Item_Identifier  Item_Fat_Content  Item_Type  \
# ...

# %%
from sklearn.linear_model import LinearRegression
lin=LinearRegression()

# %%
test=dff[dff.Item_Outlet_Sales=="test"]
train=dff[dff.Item_Outlet_Sales!="test"]
test=test.drop(["Item_Outlet_Sales"],axis=1)

# %%
from sklearn.model_selection import train_test_split
X=train.drop(["Item_Outlet_Sales"],axis=1)
y=train.Item_Outlet_Sales
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %%
model=lin.fit(X_train,y_train)

# %%
model.score(X_train,y_train)
# Out:
# 0.5104668079540116

# %%
predict=model.predict(X_test)

# %%
lin.score(X_test,y_test)
# Out:
# 0.5082094748169261

# %%
from sklearn.linear_model import Ridge
redge=Ridge(normalize=True)

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={"alpha":[1,0.9,0.8,0.7,0.6,0.5,0.4,0.3,0.2,0.1]}
p=GridSearchCV(redge,parameters,cv=3)

# %%
p.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=3, estimator=Ridge(normalize=True),
#              param_grid={'alpha': [1, 0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2,
#                                    0.1]})

# %%
p.best_params_
# Out:
# {'alpha': 0.1}

# %%
redge=Ridge(alpha=0.1,normalize=True)
model=redge.fit(X_train,y_train)

# %%
pri=model.predict(X_test)

# %%
redge.score(X_test,y_test)
# Out:
# 0.5046338383859403
